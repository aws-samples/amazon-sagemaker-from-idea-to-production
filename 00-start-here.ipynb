# %% [markdown]
# # Amazon SageMaker AI ModelOps: from idea to production in six steps

# %% [markdown]
# This sequence of six notebooks takes you from developing your ML idea in a simple notebook to a production solution with automated model building and CI/CD deployment pipelines, and model monitoring.
#
# Follow these steps one by one:
# **From idea to production in six steps:**
# ||||
# |---|---|---|
# |1. |Experiment in a notebook ||
# |2. |Scale with SageMaker AI processing jobs and SageMaker SDK ||
# |3. |Operationalize with ML pipeline, model registry ||
# |4. |Add a model building CI/CD pipeline ||
# |5. |Add a model deployment pipeline ||
# |6. |Add model and data monitoring ||
#
# To run this notebook and all notebooks in the workshop please use the `Python 3` kernel in JupyterLab

# %% [markdown]
# ## Star GitHub repository

# %%
# %%html
#
# <a class="github-button" href="https://github.com/aws-samples/amazon-sagemaker-from-idea-to-production" data-color-scheme="no-preference: light; light: light; dark: dark;" data-icon="octicon-star" data-size="large" data-show-count="true" aria-label="Star Amazon SageMaker secure MLOps on GitHub">Star</a>
# <script async defer src="https://buttons.github.io/buttons.js"></script>

# %% [markdown]
# ### Click this button ^^^ above ^^^

# %% [markdown]
# ## Setup
# Get the latest version of SageMaker Python SDK.
#
# <div style="border: 2px solid #ff9900; border-radius: 8px; padding: 15px; background-color: #fff3e0; margin-bottom: 10px;">
#     <strong>⚠️ Compatibility Notice:</strong>
# 💡 The workshop and all notebooks were tested on the <strong>SageMaker Distribution Image version <code>3.9.0</code></strong> and <strong>SageMaker Python SDK version <code>3.7.0</code></strong>
# If you encounter any incompatibility issues, you can stop the JupyterLab space and re-start it with a specific version of the SageMaker Distribution Image.
# </div>
#
#
# ![](img/jupyterlab-app-image.png)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
# %pip uninstall -y sagemaker sagemaker-core sagemaker-train sagemaker-serve sagemaker-mlops
# %pip install --no-cache-dir sagemaker-core sagemaker-train sagemaker-serve sagemaker-mlops "sagemaker>=3,<4" "mlflow==3.4.0" "sagemaker-mlflow==0.2.0"
# %pip install xgboost==3.0.5 scikit-learn==1.4.2 s3fs aiobotocore boto3
# %pip install "evidently>=0.7.20"

# %% [markdown]
# <div style="border: 4px solid #d32f2f; border-radius: 10px; padding: 20px; background-color: #ffebee; margin: 15px 0;">
#
# ### ⛔ IMPORTANT: Python 3.10 Required
#
# All notebooks in this workshop **must** run on **Python 3.10**. The cell below will fail with an `AssertionError` if you are using a different Python version.
#
# If you see an error, follow these steps:
#
# 1. Open a **Terminal** in JupyterLab (**File → New → Terminal**)
# 2. Run the setup script:
#    ```bash
#    cd ~/amazon-sagemaker-from-idea-to-production
#    ./setup-py310.sh
#    ```
# 3. **Refresh your browser** to pick up the new kernel
# 4. In this notebook, go to **Kernel → Change Kernel → Python 3.10**
# 5. **Restart the kernel** and re-run from the top
#
# </div>

# %%
import sys

assert sys.version_info[:2] == (3, 10), f"Expected Python 3.10, got {sys.version_info.major}.{sys.version_info.minor}. Please make sure you run on Python 3.10"

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# ### Check SageMaker version installed

# %%
import sagemaker
import sagemaker.core
import sagemaker.train
import sagemaker.serve
import sagemaker.mlops
from importlib.metadata import version

print(f"sagemaker: {version('sagemaker')}")
print(f"sagemaker.core: {version('sagemaker.core')}")
print(f"sagemaker.train: {version('sagemaker.train')}")
print(f"sagemaker.server: {version('sagemaker.serve')}")
print(f"sagemaker.mlops: {version('sagemaker.mlops')}")

# %% [markdown]
# ### Import packages

# %%
import json
import os
import pandas as pd

from sagemaker.core.resources import Domain
from sagemaker.core.resources import App
from sagemaker.core.resources import MlflowApp
from sagemaker.core.helper.session_helper import Session, get_execution_role
from sagemaker.core.shapes.shapes import DomainSettingsForUpdate, DockerSettings
from sagemaker.core.s3.client import S3Uploader
from sagemaker.core.s3.client import s3_path_join
from sagemaker.core.utils.utils import Unassigned
from botocore.exceptions import ClientError

# %% [markdown]
# ### Set constants
#
# SageMaker provides helper functions which can be used to fetch the default region and bucket from the current session. Although the SDK will auto-detect important variables like the execution role, these can also be fetched using the same helper functions.

# %%
session = Session()
sm_role = get_execution_role()
region = session.boto_region_name
bucket_name = session.default_bucket()
bucket_prefix = "from-idea-to-prod/xgboost"
dataset_file_local_path = "data/bank-additional/bank-additional-full.csv"
initialized = True

# %% [markdown]
# Instead of fetching the variables again in the next notebook, they can be stored using Jupyter magic.

# %%
# Store some variables to keep the value between the notebooks
# %store bucket_name
# %store bucket_prefix
# %store sm_role
# %store region
# %store initialized
# %store dataset_file_local_path

# %% [markdown]
# ### Get domain variables
# Many SageMaker Python SDK and boto3 SageMaker API calls need information about the domain. The notebook metadata file contains these values. The following code demonstrates how to access the notebook metadata file and get the variables.

# %%
def get_studio_metadata():
    metadata_file = "/opt/ml/metadata/resource-metadata.json"
    if os.path.exists(metadata_file):
        with open(metadata_file, "r") as file_handler:
            return json.load(file_handler)
    return {}


metadata = get_studio_metadata()
domain_id = metadata.get("DomainId")
user_profile_name = metadata.get("UserProfileName")
space_name = metadata.get("SpaceName")

app = App.get(
    domain_id=domain_id,
    app_type=metadata.get("AppType"),
    app_name=metadata.get("ResourceName"),
    space_name=space_name,
)
if app.resource_spec:
    image_arn = app.resource_spec.sage_maker_image_arn
    image_version_arn = app.resource_spec.sage_maker_image_version_arn
    image_version_alias = app.resource_spec.sage_maker_image_version_alias

print(f"Domain ID: {domain_id}")
print(f"Space name: {space_name}")
print(f"User profile name: {user_profile_name}")
print(f"Image ARN: {image_arn}")
print(f"Image version: {image_version_alias}")

# %%
# %store domain_id
# %store space_name
# %store user_profile_name
# %store image_arn
# %store image_version_alias

# %% [markdown]
# ### Connect to MLflow app server
#
# MLflow is an open-source platform for managing the ML lifecycle, including experiment tracking, model versioning, and deployment. SageMaker AI provides managed MLFlow Apps that integrate seamlessly with your ML workflows.
#
# **Note:** [MLflow Apps](https://docs.aws.amazon.com/sagemaker/latest/dg/mlflow-app-setup.html) are the latest managed MLflow offering on SageMaker AI and should be preferred over existing MLflow Tracking Servers. MLflow Apps offer additional features such as:
# - Serverless capability that eliminates infrastructure management
# - Faster startup time (~2 minutes)
# - Cross-account sharing via AWS RAM
# - Automatic in-place version upgrades
# - Integration with SageMaker Pipelines
#
# Let's start with an overview of MLFlow tracking features:
#
# * Organize Experiments: MLflow structures experimentation with experiments that contain multiple runs. Each run captures parameters, metrics, and artifacts from a single execution of your ML code. You can picture experiments as the top level folder for organizing your hypotheses, and runs as individual test executions within that experiment.
# * Track Experiments: MLFlow allows you to track experiments by logging parameters, metrics, and artifacts using the MLFlow API. You can use `mlflow.log_param()`, `mlflow.log_metric()`, and `mlflow.log_artifact()` to capture experiment data.
# * Compare and Evaluate Experiments: The MLFlow UI makes it easy to compare different runs, visualize metrics, and identify the best combination of hyperparameters.
#
# If you're running an AWS-led workshop or used the delivered CloudFormation template to provision your workshop environment, an MLflow app should be up and running. If you don't have an MLflow app, follow the [Developer Guide](https://docs.aws.amazon.com/sagemaker/latest/dg/mlflow-app-setup.html) or run the code cell below to create a new one.
# To create and manage an MLflow app and to work with managed MLflow experiements, you need the following permissions attached to the SageMaker execution role:
#
# ```json
# {
#     "Version":"2012-10-17",
#     "Statement": [
#         {
#             "Effect": "Allow",
#             "Action": [
#                 "sagemaker-mlflow:*",
#                 "sagemaker:CreateMlflowApp",
#                 "sagemaker:ListMlflowApps",
#                 "sagemaker:UpdateMlflowApp",
#                 "sagemaker:DeleteMlflowApp",
#                 "sagemaker:StartMlflowApp",
#                 "sagemaker:StopMlflowApp",
#                 "sagemaker:CreatePresignedMlflowAppUrl"
#             ],
#             "Resource": "*"
#         }
#     ]
# }
# ```
#
# and you need the following permissions attached to the MLflow app itself:
#
# ```json
# {
#     "Version":"2012-10-17",
#     "Statement": [
#         {
#             "Effect": "Allow",
#             "Action": [
#                 "s3:Get*",
#                 "s3:Put*",
#                 "s3:List*",
#                 "sagemaker:AddTags",
#                 "sagemaker:CreateModelPackageGroup",
#                 "sagemaker:CreateModelPackage",
#                 "sagemaker:UpdateModelPackage",
#                 "sagemaker:DescribeModelPackageGroup"
#             ],
#             "Resource": "*"
#         }
#     ]
# }
# ```
# Execute the following code to check if you have a running MLflow app.

# %%
mlflow_app = None
try:
    apps = list(MlflowApp.get_all())
    for app in apps:
        if app.status not in ("Created", "Updated"):
            continue
        if (hasattr(app, 'default_domain_id_list') and
            isinstance(app.default_domain_id_list, list) and
            domain_id in app.default_domain_id_list):
                mlflow_app = app
                print(f"Found existing default MLflow app: {mlflow_app.name}")
                break
except Exception as e:
    print(f"No default MLflow app found: {e}")

# %% [markdown]
# If no MLflow app is found, the cell below will create one.

# %%
if mlflow_app is None:
    print("Creating new default MLflow app...")
    mlflow_app = MlflowApp.create(
        name="default-mlflow-app",
        artifact_store_uri=f"s3://{bucket_name}/mlflow",
        role_arn=sm_role,
        account_default_status="ENABLED",
        model_registration_mode="AutoModelRegistrationEnabled",
        default_domain_id_list=[domain_id]
    )
    print(f"Creating MLflow app: {mlflow_app.name}")

# %% [markdown]
# Notice the `model_registration_mode="AutoModelRegistrationEnabled"` parameter above. This enables **automatic model sync** between MLflow and SageMaker: any model registered in the MLflow Model Registry via `mlflow.register_model()` is automatically synced to the [SageMaker Model Registry](https://docs.aws.amazon.com/sagemaker/latest/dg/model-registry.html) as a Model Package. This gives you a single registration action that populates both registries — you'll see this in action starting from notebook 01.

# %%
import time

while True:
    mlflow_app.refresh()
    print(f"MLflow status: {mlflow_app.status}")
    if mlflow_app.status in ("Created", "Updated"):
        break
    if "Failed" in mlflow_app.status:
        raise RuntimeError(f"MlflowApp failed with status: {mlflow_app.status}")
    time.sleep(20)

# %% [markdown]
# <div style="border: 4px solid coral; text-align: center; margin: auto;">
# Creation of an MLflow server usually takes between 1 and 2 minutes. You don't need to wait - proceed with the flow of the workshop.
# </div><br />
#
# Store the ARN and name of the MLflow app for use later.

# %%
mlflow_arn = mlflow_app.arn
mlflow_name = mlflow_app.name

print(f"\nMLflow App ARN: {mlflow_arn}")
print(f"MLflow App Name: {mlflow_name}")

# %store mlflow_arn
# %store mlflow_name

# %% [markdown]
# ## Install Docker to enable Studio local mode
#
# In notebook 02, you'll test processing and training scripts locally before running them on SageMaker managed infrastructure. This requires [Docker in Studio](https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated-local.html).
#
# The cells below will:
# 1. Enable Docker access on your SageMaker domain (if not already enabled)
# 2. Install the Docker engine in this JupyterLab space
#
# <details>
# <summary><b>⚠️ Troubleshooting: If the domain update fails</b></summary>
#
# If your execution role doesn't have `sagemaker:UpdateDomain` permission, run this in a terminal or [AWS CloudShell](https://aws.amazon.com/blogs/aws/aws-cloudshell-command-line-access-to-aws-resources/) where you have the required permissions:
#
# ```
# aws sagemaker update-domain \
#     --domain-id <your-domain-id> \
#     --domain-settings-for-update '{"DockerSettings":{"EnableDockerAccess":"ENABLED"}}'
# ```
#
# After updating, restart the JupyterLab space for the changes to take effect.
# </details>

# %%
domain = Domain.get(domain_id=domain_id)
docker_enabled = False
if (hasattr(domain, 'domain_settings') and not isinstance(domain.domain_settings, Unassigned) and
    hasattr(domain.domain_settings, 'docker_settings') and not isinstance(domain.domain_settings.docker_settings, Unassigned)):
        docker_settings = domain.domain_settings.docker_settings
        if (hasattr(docker_settings, 'enable_docker_access') and 
            not isinstance(docker_settings.enable_docker_access, Unassigned)):
            docker_enabled = docker_settings.enable_docker_access == "ENABLED"

if docker_enabled:
    print(f"Docker is already enabled for domain {domain_id}")
else:
    print(f"Enabling Docker for domain {domain_id}...")
    domain.update(
        domain_settings_for_update=DomainSettingsForUpdate(
            docker_settings=DockerSettings(
                enable_docker_access="ENABLED"
            )
        )
    )
    print("Docker has been enabled successfully")

# %%
# %%bash
#
# # see https://docs.docker.com/engine/install/ubuntu/#install-using-the-repository
# sudo apt-get update
# sudo apt-get install -y ca-certificates curl
# sudo install -m 0755 -d /etc/apt/keyrings
# sudo curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc
# sudo chmod a+r /etc/apt/keyrings/docker.asc
#
# # Add the repository to Apt sources:
# echo \
#   "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
#   $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
#   sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
# sudo apt-get update
#
# ## Currently only Docker version 20.10.X is supported in Studio: see https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated-local.html
# # pick the latest patch from:
# # apt-cache madison docker-ce | awk '{ print $3 }' | grep -i 20.10
# VERSION_STRING=5:20.10.24~3-0~ubuntu-jammy
# sudo apt-get install docker-ce-cli=$VERSION_STRING docker-compose-plugin -y
#
# # validate the Docker Client is able to access Docker Server at [unix:///docker/proxy.sock]
# docker version
# # validate the Docker Compose plugin installed
# docker compose version
#
# # Install Compose Switch. this is a replacement to the Compose V1 docker-compose (python) executable.
# # It translates the command line into Compose V2 docker compose then run the latter.
# # this is needed by the sagemaker python sdk to run in local mode
# # see https://github.com/docker/compose-switch
# curl -fL https://raw.githubusercontent.com/docker/compose-switch/master/install_on_linux.sh | sudo sh
# docker-compose version

# %% [markdown]
# ## Build a custom XGBoost container image
#
# Throughout this workshop, you'll run data processing and model training both locally and on SageMaker managed infrastructure. SageMaker provides [pre-built framework containers](https://docs.aws.amazon.com/sagemaker/latest/dg/docker-containers-prebuilt.html) for popular ML frameworks including XGBoost.
#
# However, the standard XGBoost container doesn't include everything we need for this workshop. We build a custom image that extends the official XGBoost 3.0-5 image with:
# - **`sudo`** — required by the SageMaker Python SDK's `@remote` decorator and `@step` pipeline decorator for container bootstrapping
# - **`mlflow` and `sagemaker-mlflow`** — for experiment tracking from inside training and processing containers
# - **`scikit-learn`** — used in our preprocessing code
# - **`s3fs`** — for reading data directly from S3 in pipeline steps
#
# By pre-installing these dependencies into the image, every training and pipeline job starts immediately without spending time downloading and installing packages. This significantly speeds up job startup — especially in pipelines where multiple steps run sequentially.
#
# We build this image once here and reuse it in notebooks 02, 03, and 04.
#
# > **Note:** SageMaker Studio requires `DOCKER_BUILDKIT=0` (legacy builder) and `--network sagemaker` for Docker builds.

# %%
from sagemaker.core.image_uris import retrieve

xgboost_base_image = retrieve(framework='xgboost', version='3.0-5', region=region)

dockerfile_content = f"""FROM {xgboost_base_image}
RUN apt-get update && apt-get install -y sudo && rm -rf /var/lib/apt/lists/*
# RUN ln -sf /miniconda3/bin/pip3 /usr/local/bin/pip3
RUN /miniconda3/bin/pip3 install \\
    "sagemaker>=3,<4" \\
    sagemaker-mlflow==0.2.0 \\
    mlflow==3.4.0 \\
    scikit-learn==1.4.2 \\
    s3fs==2026.3.0 \\
    setuptools==81.0.0 \\
    cloudpickle==3.1.2 \\
    "protobuf>=3.20.0,<3.21" \\
    "Flask>=2.0,<3.0" \\
    "Jinja2>=3.0,<3.2" \\
"""

dockerfile_path = "Dockerfile.xgboost-custom"
with open(dockerfile_path, "w") as f:
    f.write(dockerfile_content)

print(f"Base image: {xgboost_base_image}")
print(f"Dockerfile written to: {dockerfile_path}")
print()
print(dockerfile_content)

account_id = session.account_id()
ecr_repo = "sagemaker-xgboost-custom"
image_tag = "3.0-5"
custom_xgboost_image = f"{account_id}.dkr.ecr.{region}.amazonaws.com/{ecr_repo}:{image_tag}"

print(f"Custom image URI: {custom_xgboost_image}")

# %%
# %%bash -s "$xgboost_base_image" "$custom_xgboost_image" "$region" "$ecr_repo"
#
# BASE_IMAGE=$1
# CUSTOM_IMAGE=$2
# REGION=$3
# REPO_NAME=$4
# ACCOUNT_ID=$(echo $CUSTOM_IMAGE | cut -d. -f1)
# SOURCE_ACCOUNT=$(echo $BASE_IMAGE | cut -d. -f1)
#
# # Authenticate to source ECR and pull base image
# aws ecr get-login-password --region $REGION | docker login --username AWS --password-stdin ${SOURCE_ACCOUNT}.dkr.ecr.${REGION}.amazonaws.com
# docker pull $BASE_IMAGE
#
# # Create target ECR repository if it doesn't exist
# aws ecr describe-repositories --repository-names $REPO_NAME --region $REGION 2>/dev/null || \
#     aws ecr create-repository --repository-name $REPO_NAME --region $REGION
#
# docker build --network sagemaker -t $CUSTOM_IMAGE -f Dockerfile.xgboost-custom .
#
# # Push to your account's ECR
# aws ecr get-login-password --region $REGION | docker login --username AWS --password-stdin ${ACCOUNT_ID}.dkr.ecr.${REGION}.amazonaws.com
# docker push $CUSTOM_IMAGE
#
# echo "Done: $CUSTOM_IMAGE"

# %%
xgboost_image = custom_xgboost_image
print(f"XGBoost image: {xgboost_image}")

# %store xgboost_image

# %% [markdown]
# ## Data

# %% [markdown]
# This example uses the [direct marketing dataset](https://archive.ics.uci.edu/ml/datasets/bank+marketing) from UCI's ML Repository:
# > [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014
#
# The data is relates to direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to assess if the product (bank term deposit) would be subscribed to ('yes') or not ('no').
#
# First, download and unzip the dataset.

# %%
# !wget -P data/ -N https://archive.ics.uci.edu/static/public/222/bank+marketing.zip --no-check-certificate

# %%
import zipfile

with zipfile.ZipFile("data/bank+marketing.zip", "r") as z:
    print("Unzipping bank+marketing...")
    z.extractall("data")

with zipfile.ZipFile("data/bank-additional.zip", "r") as z:
    print("Unzipping bank-additional...")
    z.extractall("data")

print("Done")

# %% [markdown]
# Now load the dataset into a data frame so you can take a look at what you'll be working with.

# %%
df_data = pd.read_csv(dataset_file_local_path, sep=";")
pd.set_option("display.max_columns", 500)  # View all of the columns
df_data  # show first 5 and last 5 rows of the dataframe

# %% [markdown]
# ### Upload dataset to S3
#
# Various SageMaker features, like training jobs, will load the dataset from S3. The cell below uploads the data to the default S3 bucket.

# %%
local_path = "data/bank-additional/bank-additional-full.csv"
s3_uri = s3_path_join("s3://", bucket_name, bucket_prefix, "input")
s3_data_uri = S3Uploader.upload(local_path, s3_uri)
print(f"Uploaded file to {s3_data_uri}")

# %% [markdown]
# And store the S3 URI of the uploaded dataset for future use.

# %%
# %store s3_data_uri

# %% [markdown]
# ## Restart kernel
#
# Restarting the kernel between notebooks can be helpful to free up space.

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)

# %% [markdown]
# ## Further workshop flow
# You can continue the workshop by going through each of the following notebooks in the direct order, e.g. 1-2-3-4....
#
# If you're interested in a particular topic, you can execute some notebooks standalone, as shown in the following flow diagram:
#
# ![](img/workshop-flow.png)
#
# Start with the step 1 [Idea Development](01-idea-development.ipynb) or step 3 [SageMaker Pipelines](03-sagemaker-pipeline.ipynb).

# %% [markdown]
# ## Additional resources

# %% [markdown]
# ### Documentation
# - [SageMaker Python SDK v3](https://sagemaker.readthedocs.io/en/stable/)
# - [Amazon SageMaker Studio](https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated.html)
# - [MLflow Apps in SageMaker](https://docs.aws.amazon.com/sagemaker/latest/dg/mlflow-app-setup.html)
# - [Local mode in SageMaker AI Studio](https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated-local.html)

# %% [markdown]
# ### Hands-on examples
# - [Official Amazon SageMaker Examples repository](https://github.com/aws/amazon-sagemaker-examples)
# - [Community Amazon SageMaker Examples repository](https://github.com/aws/amazon-sagemaker-examples-community)

# %% [markdown]
# ### Workshops
# - [Amazon SageMaker 101 Workshop](https://catalog.us-east-1.prod.workshops.aws/workshops/0c6b8a23-b837-4e0f-b2e2-4a3ffd7d645b/en-US)
# - [Amazon SageMaker AI Immersion Day](https://catalog.us-east-1.prod.workshops.aws/workshops/63069e26-921c-4ce1-9cc7-dd882ff62575)
